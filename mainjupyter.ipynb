# %%
#extract stocks from S&P500 for given criteria
import scipy as sp
import pandas_datareader as web
import pandas as pd
from yahoo_fin import stock_info as si
import datetime as dt

tickers = si.tickers_sp500()

start = dt.datetime.now() - dt.timedelta(days=365)
end = dt.datetime.now()

sp500_df = web.DataReader('^GSPC','yahoo',start,end)
sp500_df['Pct Change']= sp500_df['Adj Close'].pct_change()
sp500_return = (sp500_df['Pct Change'] + 1).cumprod()[-1]

#comparing individual stocks to the S&P500 ETF
return_list = []
#Endter the interested compare after columns
final_df = pd.DataFrame(columns=['Ticker','Latest_Price','Score','PE_Ratio','PEG_Ratio','SMA_150','SMA_200','52_Week_Low','52_Week_High'])

for ticker in tickers:
    df = web.DataReader(ticker,'yahoo',start,end)
    df.to_csv(f'stock_data/{ticker}.csv')

    df['Pct Change'] = df['Adj Close'].pct_change()
    stock_return = (df['Pct Change']+1).cumprod()[-1]

    returns_compared = round((stock_return/ sp500_return), 2)
    return_list.append(returns_compared)

#Filter out the best performance(top 10 percent) 12:27

best_performers = pd.DataFrame(list(zip(ticker, return_list)), columns=['Ticker','Returns Compared'])
best_performers['Score'] = best_performers['Returns Compared'].rank(pct=True)* 100
best_performers = best_performers[best_performers['Score']>= best_performers['Score'].quantile(0.9)]

for ticker in best_performers['Ticker']:
    try:
        df = pd.read_csv(f'stock_data/{ticker}.csv', index_col=0)
        moving_averages =[150,200]
        for ma in moving_averages:
            df['SMA_'+str(ma)] = round(df['Adj Close'].rolling(window= ma).mean(), 2)
        latest_price= df['Adj Close'][-1]
        pe_ratio = float(si.get_quote_table(ticker)['PE Ratio (TTM)'])
        peg_ratio = float(si.get_stats_valuation(ticker)[1][4])
        moving_average_150 = df['SMA_150'][-1]
        moving_average_200 = df['SMA_200'][-1]
        low_52week = round(min(df['Low'][-(52*5):]),2)
        high_52week = round(max(df['High'][-(52*5):]),2)
        score = round(best_performers[best_performers['Ticker']== ticker]['Score'].tolist()[0])

        #Enter the conditions Here
        condition_1 = latest_price > moving_average_150 > moving_average_200
        condition_2 = latest_price >= (1.50 *low_52week)
        condition_3 = latest_price >= (0.50 *high_52week)
        condition_4 = pe_ratio < 30
        condition_5 = peg_ratio < 2

        #if condition_1 and condition_2 and condition_3 and condition_4 and condition_5 :
        if condition_4 and condition_5 :
            final_df = final_df.append({'Ticker':ticker,
                                         'Latest_Price': latest_price,
                                         'Score': score,
                                         'PE_Ratio': pe_ratio,
                                         'PEG_Ratio': peg_ratio,
                                         'SMA_150': moving_average_150,
                                         'SMA_200': moving_average_200,
                                         '52_Week_Low': low_52week,
                                         '52_Week_High': high_52week}, ignore_index= True)
    except Exception as e:
        print(f'{e} for {ticker}')


#final Sorting

final_df.sort_values(by='Score', ascending= False)
pd.set_option('display.max_columns',10)
print(final_df)
final_df.to_csv('final.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\User\Desktop\Stock Screener\mainjupyter.ipynb Cell 1' in <cell line: 22>()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Stock%20Screener/mainjupyter.ipynb#ch0000000?line=19'>20</a> final_df = pd.DataFrame(columns=['Ticker','Latest_Price','Score','PE_Ratio','PEG_Ratio','SMA_150','SMA_200','52_Week_Low','52_Week_High'])
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Stock%20Screener/mainjupyter.ipynb#ch0000000?line=21'>22</a> for ticker in tickers:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Stock%20Screener/mainjupyter.ipynb#ch0000000?line=22'>23</a>     df = web.DataReader(ticker,'yahoo',start,end)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Stock%20Screener/mainjupyter.ipynb#ch0000000?line=23'>24</a>     df.to_csv(f'stock_data/{ticker}.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Stock%20Screener/mainjupyter.ipynb#ch0000000?line=25'>26</a>     df['Pct Change'] = df['Adj Close'].pct_change()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=204'>205</a>     else:
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=205'>206</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=206'>207</a> return func(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=366'>367</a>     raise NotImplementedError(msg)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=368'>369</a> if data_source == "yahoo":
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=369'>370</a>     return YahooDailyReader(
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=370'>371</a>         symbols=name,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=371'>372</a>         start=start,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=372'>373</a>         end=end,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=373'>374</a>         adjust_price=False,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=374'>375</a>         chunksize=25,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=375'>376</a>         retry_count=retry_count,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=376'>377</a>         pause=pause,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=377'>378</a>         session=session,
# --> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=378'>379</a>     ).read()
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=380'>381</a> elif data_source == "iex":
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=381'>382</a>     return IEXDailyReader(
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=382'>383</a>         symbols=name,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=383'>384</a>         start=start,
#    (...)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=389'>390</a>         session=session,
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/data.py?line=390'>391</a>     ).read()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/base.py?line=250'>251</a> # If a single symbol, (e.g., 'GOOG')
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/base.py?line=251'>252</a> if isinstance(self.symbols, (string_types, int)):
# --> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/base.py?line=252'>253</a>     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/base.py?line=253'>254</a> # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/base.py?line=254'>255</a> elif isinstance(self.symbols, DataFrame):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_datareader\yahoo\daily.py:161, in YahooDailyReader._read_one_data(self, url, params)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/yahoo/daily.py?line=158'>159</a> prices = DataFrame(data["prices"])
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/yahoo/daily.py?line=159'>160</a> prices.columns = [col.capitalize() for col in prices.columns]
# --> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/yahoo/daily.py?line=160'>161</a> prices["Date"] = to_datetime(to_datetime(prices["Date"], unit="s").dt.date)
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/yahoo/daily.py?line=162'>163</a> if "Data" in prices.columns:
#     <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas_datareader/yahoo/daily.py?line=163'>164</a>     prices = prices[prices["Data"].isnull()]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/User/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'Date'
